# %%
import pandas as pd

# %%
# CSV
pd.options.display.max_columns = 5 # set how many col to print
bookcsv = pd.read_csv('Bookcsv.csv')
print(bookcsv.head(5))
# Out:
#    data_lenth   frameIdx  ...    angle_Idx   SNR
# 0          49      32735  ...          255    31
# 1          49      32736  ...          255    31
# 2          68      32737  ...          255    31
# 3          68      32737  ...          255    16
# 4          49      32738  ...          255    31
#
# [5 rows x 17 columns]

# %%
# TXT
# all using csv to read
booktsv = pd.read_csv('Booktsv.tsv', sep = ',')
print(booktsv.head(5))
# Out:
#    data_lenth   frameIdx  ...    angle_Idx   SNR
# 0          49      32735  ...          255    31
# 1          49      32736  ...          255    31
# 2          68      32737  ...          255    31
# 3          68      32737  ...          255    16
# 4          49      32738  ...          255    31
#
# [5 rows x 17 columns]

# %%
# TSV
booktxt = pd.read_csv('Booktxt.txt', sep = ',')
print(booktxt.head(5))
# Out:
#    data_lenth   frameIdx  ...    angle_Idx   SNR
# 0          49      32735  ...          255    31
# 1          49      32736  ...          255    31
# 2          68      32737  ...          255    31
# 3          68      32737  ...          255    16
# 4          49      32738  ...          255    31
#
# [5 rows x 17 columns]
