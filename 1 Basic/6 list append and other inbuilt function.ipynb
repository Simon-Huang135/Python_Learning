# %%
a = [1, 3, 5, 7, 9, 11]

# %%
# append
b = []
b.append(10)
b.append(20)
print(b)
# Out:
# [10, 20]

# %%
# for loop for list append
c = []
for element in a:
    c.append(element*2)
print(c)

d = []
for i in range(len(a)):
    d.append(a[i]*2)
print(d)

e = [element * 2 for element in a]
print(e)
# Out:
# [2, 6, 10, 14, 18, 22]
# [2, 6, 10, 14, 18, 22]
# [2, 6, 10, 14, 18, 22]

# %%
# [1, 4, 9, 16, 25, 36] # for loop for list append
f = []
for i in range(1, 7):
    f.append(i**2)
print(f)

g = [i ** 2 for i in range(1, 7)]
print(g)
# Out:
# [1, 4, 9, 16, 25, 36]
# [1, 4, 9, 16, 25, 36]

# %%
# [36, 25, 16, 9, 4, 1] while for loop for list append
h0 = []
i = 6
while i > 0:
    h0.append(i ** 2)
    i -= 1
print(h1)

h1 = []
for i in range(6, 0, -1):
    h1.append(i ** 2)
print(h1)

h2 = [i ** 2 for i in range(6, 0, -1)]
print(h2)
# Out:
# [36, 25, 16, 9, 4, 1]
# [36, 25, 16, 9, 4, 1]
# [36, 25, 16, 9, 4, 1]

# %%
# other inbuilt function
a = [1, 2, 3 ,3, 5, 6 ,7]

a.insert(1, 0) # inser 0 in index 1
print(a)

a.remove(3) # remove number 3 present at first
print(a)

c = a.index(1)
print(c)

a.sort(reverse = True)
print(a)
# Out:
# [1, 0, 2, 3, 3, 5, 6, 7]
# [1, 0, 2, 3, 5, 6, 7]
# 0
# [7, 6, 5, 3, 2, 1, 0]
