# %%
try:
    file = open('eee', 'a+') # r+, etc. (file handling) a+: Opens a file for both appending and reading.
except Exception as e:
    print(e)
    response = input('do u want to create a new file ? ')
    if response == 'y':
        file = open('eee', 'w')
    else:
        pass
    
else: # following the try, if try suceess
    file.write('ssss\n')
    print('write success')
file.close()

# check what in there
f = open('eee', 'r')
a =f.read()
print(a)

file.close()
# Out:
# write success
# ssssssssssssssssssssssssssss
# ssss
# ssss
# ssss
# ssss
# ssss
# ssss
# ssss
# ssss
