# %%
a = {} # or dict()

# %%
a["George"] = 24

# %%
a["Tom"] = 32
a["Jenny"] = 16

# %%
print(a["Tom"])
# Out:
# 32

# %%
a[10] = 100

# %%
print(a[10])
# Out:
# 100

# %%
# iteration in dictionary
for key, value in a.items():
    print(key, "->", value)
# Out:
# George -> 24
# Tom -> 32
# Jenny -> 16
# 10 -> 100

# %%
print(a)
# Out:
# {'George': 24, 'Tom': 32, 'Jenny': 16, 10: 100}
