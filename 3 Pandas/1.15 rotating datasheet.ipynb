# %%
import pandas as pd

# %%
books = pd.read_excel('Book13.xlsx', index_col = 'Month')
print(books)

# pd.options.display.max_columns = 999
table = books.transpose()
print(table)
# Out:
#        Activer User  Page View
# Month
# Jan            1000       3500
# Feb            1500       4500
# Mar            2250       5500
# Apr            3375       6500
# May            5063       7500
# Jun            7595       8500
# Jul           11393       9500
# Aug           17090      10500
# Sep           25063      11500
# Oct           38080      12500
# Nov           57896      13500
# Dec           86573      14500
# Month          Jan   Feb   Mar   Apr   May   Jun    Jul    Aug    Sep    Oct  \
# Activer User  1000  1500  2250  3375  5063  7595  11393  17090  25063  38080
# Page View     3500  4500  5500  6500  7500  8500   9500  10500  11500  12500
#
# Month           Nov    Dec
# Activer User  57896  86573
# Page View     13500  14500
