# %%
import pandas as pd

# %%
# split and expand to to col
books = pd.read_excel('Book11.xlsx', index_col = 'ID')
print(books)

df = books['Name'].str.split(' ', expand = True)
books['First Name'] = df[0]
books['Last Name'] = df[1].str.upper()
books = books.drop(columns = 'Name')
print(books)
# Out:
#            Name
# ID
# 1    Syed Abbas
# 2   Simon Huang
# 3   Telina Zeng
# 4     Tim Zhang
# 5    Syed Abbas
# 6   Simon Huang
# 7   Telina Zeng
# 8     Tim Zhang
# 9    Syed Abbas
# 10  Simon Huang
# 11  Telina Zeng
# 12    Tim Zhang
# 13   Syed Abbas
# 14  Simon Huang
# 15  Telina Zeng
# 16    Tim Zhang
# 17   Syed Abbas
# 18  Simon Huang
# 19  Telina Zeng
# 20    Tim Zhang
#    First Name Last Name
# ID
# 1        Syed     ABBAS
# 2       Simon     HUANG
# 3      Telina      ZENG
# 4         Tim     ZHANG
# 5        Syed     ABBAS
# 6       Simon     HUANG
# 7      Telina      ZENG
# 8         Tim     ZHANG
# 9        Syed     ABBAS
# 10      Simon     HUANG
# 11     Telina      ZENG
# 12        Tim     ZHANG
# 13       Syed     ABBAS
# 14      Simon     HUANG
# 15     Telina      ZENG
# 16        Tim     ZHANG
# 17       Syed     ABBAS
# 18      Simon     HUANG
# 19     Telina      ZENG
# 20        Tim     ZHANG
