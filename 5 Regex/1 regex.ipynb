# %%
import re

# %%
# matching string without re

pattern1 = "cat"
pattern2 = "bird"
string = "dog runs to cat"

print(pattern1 in string) 
print(pattern2 in string)
# Out:
# True
# False

# %%
# regular expression re.search

pattern1 = "cat"
pattern2 = "bird"
string = "dog runs to cat"
print(re.search(pattern1, string)) # use re.search to find the index range of the pattern in string
print(re.search(pattern2, string)) # if none, then none
# Out:
# <re.Match object; span=(12, 15), match='cat'>
# None

# %%
# multiple patterns search

ptn = r"r[au]n" # ("run" or "ran")     r'this is the expression'
print(re.search(ptn, "dog runs to cat"))
# Out:
# <re.Match object; span=(4, 7), match='run'>

# %%
# continue

print(re.search(r"r[A-Z]n", "dog runs to cat"))     
print(re.search(r"r[a-z]n", "dog runs to cat"))     
print(re.search(r"r[0-9]n", "dog r2ns to cat"))     
print(re.search(r"r[0-9a-z]n", "dog runs to cat"))
# Out:
# None
# <re.Match object; span=(4, 7), match='run'>
# <re.Match object; span=(4, 7), match='r2n'>
# <re.Match object; span=(4, 7), match='run'>

# %% [markdown]
# # Digit

# %%
# digit

# \d : decimal digit
print(re.search(r"r\dn", "run r4n")) # find all the decimal digit index range             
# \D : any non-decimal digit
print(re.search(r"r\Dn", "run r4n")) # find all the non-decimal digit index range
# Out:
# <re.Match object; span=(4, 7), match='r4n'>
# <re.Match object; span=(0, 3), match='run'>

# %% [markdown]
# # blank

# %%
# blank

# \s : any white space [\t\n\r\f\v]
print(re.search(r"r\sn", "r\nn r4n")) # find all tap, return, ... index range         
# \S : opposite to \s, any non-white space
print(re.search(r"r\Sn", "r\nn r4n")) # find all non-blank index range
# Out:
# <re.Match object; span=(0, 3), match='r\nn'>
# <re.Match object; span=(4, 7), match='r4n'>

# %% [markdown]
# # all number, characters, _

# %%
# \w : [a-zA-Z0-9_]
print(re.search(r"r\wn", "r\nn r4n"))               
# \W : opposite to \w
print(re.search(r"r\Wn", "r\nn r4n"))
# Out:
# r
# n r4n
# <re.Match object; span=(4, 7), match='r4n'>
# <re.Match object; span=(0, 3), match='r\nn'>

# %% [markdown]
# # Special characters

# %%
# special characters

# \\ : match \
print(re.search(r"runs\\", "runs\ to me"))          
# . : match anything (except \n)
print(re.search(r"r.n", "r[ns to me"))
# Out:
# <re.Match object; span=(0, 5), match='runs\\'>
# <re.Match object; span=(0, 3), match='r[n'>

# %% [markdown]
# # line head or tail

# %%
# line head or tail

# ^ : match line beginning
print(re.search(r"^dog", "dog runs to cat"))        
# $ : match line ending
print(re.search(r"cat$", "dog runs to cat"))
# Out:
# <re.Match object; span=(0, 3), match='dog'>
# <re.Match object; span=(12, 15), match='cat'>

# %% [markdown]
# # whether or not

# %%
# whether or not

# ? : may or may not occur
print(re.search(r"Mon(day)?", "Monday"))            
print(re.search(r"Mon(day)?", "Mon"))
# Out:
# <re.Match object; span=(0, 6), match='Monday'>
# <re.Match object; span=(0, 3), match='Mon'>

# %% [markdown]
# # multi-line

# %%
# multi-line

string = """
dog runs to cat.
I run to dog.
"""
print(re.search(r"^I", string))                     
print(re.search(r"^I", string, flags=re.M))
# Out:
# None
# <re.Match object; span=(18, 19), match='I'>

# %% [markdown]
# # occur or more times

# %%
# * : occur 0 or more times

print(re.search(r"ab*", "a"))                       
print(re.search(r"ab*", "abbbbb"))
# Out:
# <re.Match object; span=(0, 1), match='a'>
# <re.Match object; span=(0, 6), match='abbbbb'>

# %%
# + : occur 1 or more times

print(re.search(r"ab+", "a"))                       
print(re.search(r"ab+", "abbbbb"))
# Out:
# None
# <re.Match object; span=(0, 6), match='abbbbb'>

# %%
# {n, m} : occur n to m times
print(re.search(r"ab{2,10}", "a"))                  
print(re.search(r"ab{2,10}", "abbbbb"))
# Out:
# None
# <re.Match object; span=(0, 6), match='abbbbb'>

# %% [markdown]
# # group

# %%
# group

match = re.search(r"(\d+), Date: (.+)", "ID: 021523, Date: Feb/12/2017")
print(match.group())                                
print(match.group(1))                               
print(match.group(2))

print('')

match = re.search(r"(?P<id>\d+), Date: (?P<date>.+)", "ID: 021523, Date: Feb/12/2017")
print(match.group('id'))                            
print(match.group('date'))
# Out:
# 021523, Date: Feb/12/2017
# 021523
# Feb/12/2017
#
# 021523
# Feb/12/2017

# %% [markdown]
# # find all

# %%
# findall

print(re.findall(r"r[ua]n", "run ran ren"))

# | : or
print(re.findall(r"(run|ran)", "run ran ren"))
# Out:
# ['run', 'ran']

# %% [markdown]
# # re.sub() replace

# %%
# re.sub() replace

print(re.sub(r"r[au]ns", "catches", "dog runs to cat"))
# Out:
# dog catches to cat

# %% [markdown]
# # re.split()

# %%
# re.split()

print(re.split(r"[,;\.]", "a;b,c.d;e"))
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
# compile

compiled_re = re.compile(r"r[ua]n")
print(compiled_re.search("dog ran to cat"))
# Out:
# <re.Match object; span=(4, 7), match='ran'>
