# %%
a=[3, 10, -1]
type(a[0])
# Out:
# int

# %%
print (a)
# Out:
# [3, 10, -1]

# %%
a.append(1)
print(a)
# Out:
# [3, 10, -1, 1]

# %%
a.append("hello")
print(a)
type(a[-1])
# Out:
# [3, 10, -1, 'hello', 'hello']
# str

# %%
a.append([1,2])
print(a)
type([-1][-1])
# Out:
# [3, 10, -1, 'hello', 'hello', [1, 2], [1, 2]]
# int

# %%
a.pop()
print(a)
# Out:
# [3, 10, -1, 1, 'hello']

# %%
a[0] = 100
print(a)
# Out:
# [100, 10, -1, 'hello', 'hello', [1, 2], [1, 2]]

# %%
# swap b[0] and b[2]
b = ['banana', 'apple', 'microsoft']
temp = b[0]
b[0] = b[2]
b[2] = temp0
print(b)
# Out:
# ['microsoft', 'apple', 'banana']
